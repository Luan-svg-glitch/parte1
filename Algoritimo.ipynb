# %% [markdown]
# #cometarios
# importantes para documentar o codigo
#
#  boas praticas
#
#
# *   nâo comentar codigo errado
# *   nâo comentar codigo teste(produção)
#
# comentario de uma linha()
#
#   (#) usar para comentar uma linha do codigo
#
#   comentario de multiplas linhas
#
#   """"""usar para cabeçalho do codigo
#   usar 3 aspar
#   """"

# %% [markdown]
# Operadores Aritimeticos

# %%
#Adição
10 + 2
# Out:
# 12

# %%
#Subtração
10 - 2

# %%
#Divisão
10 / 2

# %%
#Multiplicação
10 * 2

# %%
#Resto da divisão
11 % 2

# %%
#Potencialização
10 ** 2
# Out:
# 100

# %% [markdown]
# Operadores Relacionais

# %%
#Menor
10 < 2

# %%
#Menor ou igual
10 <= 2

# %%
#Maior
10 > 2

# %%
#Maior ou igual
10 >- 2

# %%
#Igual
7 == 7

# %%
#Diferente
7!= 7

# %% [markdown]
# Operadores Logicos

# %% [markdown]
# *  and
# *  or
# *  not

# %% [markdown]
# Tabela verdade

# %%
print(10 > 2 and 4 < 6) #V and V - V
print(10 > 2 and 4 > 6) #V and F - F
print(10 < 2 and 4 > 6) #F and V - F
print(10 < 2 and 4 < 6) #F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
print(10 > 2 or 4 < 6) #V or V - V
print(10 > 2 or 4 > 6) #V or F - V
print(10 < 2 or 4 > 6) #F or V - V
print(10 < 2 or 4 < 6) #F or F - F
# Out:
# True
# True
# False
# True

# %% [markdown]
# Not

# %%
not 10 > 2 # V - F
# Out:
# False

# %%
not 10 < 2 # F - V
# Out:
# True
